# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import astropy.units as u
from scipy import stats
from scipy.optimize import minimize
from IPython.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
# establish data generation and have a look at the synthetic data

n = 1000 # number of data points in sample
x = stats.uniform(0, 1).rvs(n) # n random variables from uniform distribution

a = 0.5
b = 1
sigma_y = 0.05

y = a*x + b + stats.norm(0, sigma_y).rvs(n) # linear function of x with a gaussian error of width sigma_y

plt.plot(x, y, 'x')

# %%
# define the proper functions and test id everything works

def generate_data(n, a, b, sigma_x, sigma_y):
    x = stats.uniform(0, 1).rvs(n) + stats.norm(0, sigma_x).rvs(n)
    y = a*x + b + stats.norm(0, sigma_y).rvs(n)
    return x, y

a, b, sigma_x,sigma_y = 0.5, 1, 0, 0.05 # for the first part sigma_x = 0

x_, y_ = generate_data(10, a, b, sigma_x, sigma_y)

def Chi2(params, x_,y_, sigma_y):
    return np.sum(((y_ - params[0]*x_ - params[1])/sigma_y)**2)

minimize(Chi2, x0=(0, 0), args = (x_, y_, sigma_y))
# Out:
#       fun: 18.995016944312564
#  hess_inv: array([[ 0.00176201, -0.00062714],
#        [-0.00062714,  0.00034821]])
#       jac: array([ 4.52995300e-06, -2.38418579e-07])
#   message: 'Optimization terminated successfully.'
#      nfev: 21
#       nit: 4
#      njev: 7
#    status: 0
#   success: True
#         x: array([0.52505333, 0.99112204])

# %%
n_experiments = 1000
n = 10

a_values = np.zeros(n_experiments)
b_values = np.zeros(n_experiments)

a, b, sigma_x,sigma_y = 0.5, 1, 0, 0.05 # for the first part sigma_x = 0


for i in range(n_experiments):
    x_, y_ = generate_data(10, a, b, sigma_x, sigma_y) # generate samples of n points 
    a_values[i], b_values[i] = minimize(Chi2, x0=(0, 0), args = (x_, y_, sigma_y)).x # find the best fit parameters for a and b
    
# plot the distribution of estimated a and b values
n_bins = 25

fig, axs = plt.subplots(1, 2, figsize=(12, 4))
axs[0].hist(a_values, bins=n_bins, density=True, alpha=0.5, label='a')
axs[0].axvline(a, color='C0', label='True a')
axs[0].legend()
axs[1].hist(b_values, bins=n_bins, density=True, alpha=0.5, label='b')
axs[1].axvline(b, color='C1', label='True b')
axs[1].legend()

for ax in axs:
    ax.set_xlabel('Parameter Value from Fit')
    ax.set_ylabel('Count')
plt.show()

print('from estimator: a = {:.2f} +/- {:.2f}'.format(np.mean(a_values), np.std(a_values)))
print('from estimator: b = {:.2f} +/- {:.2f}'.format(np.mean(b_values), np.std(b_values)))
# Out:
# from estimator: a = 0.50 +/- 0.06
# from estimator: b = 1.00 +/- 0.04

# %% [markdown]
# ### Non-zero error in x

# %%
n_experiments = 1000
n = 10

a_values = np.zeros(n_experiments)
b_values = np.zeros(n_experiments)

a, b, sigma_x, sigma_y = 0.5, 1, 0.05, 0.05 # now sigma_x = 0.05


for i in range(n_experiments):
    x_, y_ = generate_data(10, a, b, sigma_x, sigma_y) # generate samples of n points 
    a_values[i], b_values[i] = minimize(Chi2, x0=(0, 0), args = (x_, y_, sigma_y)).x # find the best fit parameters for a and b
    
# plot the distribution of estimated a and b values
n_bins = 25

fig, axs = plt.subplots(1, 2, figsize=(12, 4))
axs[0].hist(a_values, bins=n_bins, density=True, alpha=0.5, label='a')
axs[0].axvline(a, color='C0', label='True a')
axs[0].legend()
axs[1].hist(b_values, bins=n_bins, density=True, alpha=0.5, label='b')
axs[1].axvline(b, color='C1', label='True b')
axs[1].legend()

for ax in axs:
    ax.set_xlabel('Parameter Value from Fit')
    ax.set_ylabel('Count')
plt.show()

print('from estimator: a = {:.2f} +/- {:.2f}'.format(np.mean(a_values), np.std(a_values)))
print('from estimator: b = {:.2f} +/- {:.2f}'.format(np.mean(b_values), np.std(b_values)))
# Out:
# from estimator: a = 0.50 +/- 0.06
# from estimator: b = 1.00 +/- 0.04

# %% [markdown]
# ### increasing the x error

# %%
n_experiments = 1000
n = 10

a_values = np.zeros(n_experiments)
b_values = np.zeros(n_experiments)

a, b, sigma_x, sigma_y = 0.5, 1, 0.2, 0.2 # now sigma_x = 0.2 and sigma_y = 0.2


for i in range(n_experiments):
    x_, y_ = generate_data(10, a, b, sigma_x, sigma_y) # generate samples of n points 
    a_values[i], b_values[i] = minimize(Chi2, x0=(0, 0), args = (x_, y_, sigma_y)).x # find the best fit parameters for a and b
    
# plot the distribution of estimated a and b values
n_bins = 25

fig, axs = plt.subplots(1, 2, figsize=(12, 4))
axs[0].hist(a_values, bins=n_bins, density=True, alpha=0.5, label='a')
axs[0].axvline(a, color='C0', label='True a')
axs[0].legend()
axs[1].hist(b_values, bins=n_bins, density=True, alpha=0.5, label='b')
axs[1].axvline(b, color='C1', label='True b')
axs[1].legend()

for ax in axs:
    ax.set_xlabel('Parameter Value from Fit')
    ax.set_ylabel('Count')
plt.show()

print('from estimator: a = {:.2f} +/- {:.2f}'.format(np.mean(a_values), np.std(a_values)))
print('from estimator: b = {:.2f} +/- {:.2f}'.format(np.mean(b_values), np.std(b_values)))
# Out:
# from estimator: a = 0.50 +/- 0.21
# from estimator: b = 1.00 +/- 0.13

# %% [markdown]
# ### increasing $n$

# %%
n_experiments = 1000
n = 50

a_values = np.zeros(n_experiments)
b_values = np.zeros(n_experiments)

a, b, sigma_x, sigma_y = 0.5, 1, 0.2, 0.2 # now sigma_x = 0.2 and sigma_y = 0.2


for i in range(n_experiments):
    x_, y_ = generate_data(10, a, b, sigma_x, sigma_y) # generate samples of n points 
    a_values[i], b_values[i] = minimize(Chi2, x0=(0, 0), args = (x_, y_, sigma_y)).x # find the best fit parameters for a and b
    
# plot the distribution of estimated a and b values
n_bins = 25

fig, axs = plt.subplots(1, 2, figsize=(12, 4))
axs[0].hist(a_values, bins=n_bins, density=True, alpha=0.5, label='a')
axs[0].axvline(a, color='C0', label='True a')
axs[0].legend()
axs[1].hist(b_values, bins=n_bins, density=True, alpha=0.5, label='b')
axs[1].axvline(b, color='C1', label='True b')
axs[1].legend()

for ax in axs:
    ax.set_xlabel('Parameter Value from Fit')
    ax.set_ylabel('Count')
plt.show()

print('from estimator: a = {:.2f} +/- {:.2f}'.format(np.mean(a_values), np.std(a_values)))
print('from estimator: b = {:.2f} +/- {:.2f}'.format(np.mean(b_values), np.std(b_values)))
# Out:
# from estimator: a = 0.49 +/- 0.21
# from estimator: b = 1.01 +/- 0.12
